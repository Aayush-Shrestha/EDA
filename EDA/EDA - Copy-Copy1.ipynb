# %%
library(readxl)
library(tidyverse)
library(ggplot2)
library(grid)
library(gridExtra)

# %%
df <- read_excel("train.xlsx")
head(df)
# Out:
#   Patient Id Patient Age Genes in mother's side Inherited from father
# 1 PID0x6418   2          Yes                    No
# 2 PID0x25d5   4          Yes                    Yes
# 3 PID0x4a82   6          Yes                    No
# 4 PID0x4ac8  12          Yes                    No
# 5 PID0x1bf7  11          Yes                    No
# 6 PID0x44fe  14          Yes                    No
#   Maternal gene Paternal gene Blood cell count (mcL) Patient First Name
# 1 Yes           No            4.760603               Richard
# 2 No            No            4.910669               Mike
# 3 No            No            4.893297               Kimberly
# 4 Yes           No            4.705280               Jeffery
# 5 NA            Yes           4.720703               Johanna
# 6 Yes           No            5.103188               Richard
#   Family Name Father's name ... Birth defects
# 1 NA          Larre         ... NA
# 2 NA          Brycen        ... Multiple
# ...

# %%
summary(df)
# Out:
#   Patient Id         Patient Age     Genes in mother's side
#  Length:22083       Min.   : 0.000   Length:22083
#  Class :character   1st Qu.: 3.000   Class :character
#  Mode  :character   Median : 7.000   Mode  :character
#                     Mean   : 6.974
#                     3rd Qu.:11.000
#                     Max.   :14.000
#                     NA's   :1427
#  Inherited from father Maternal gene      Paternal gene
#  Length:22083          Length:22083       Length:22083
#  Class :character      Class :character   Class :character
#  Mode  :character      Mode  :character   Mode  :character
#
#
#
#
#  Blood cell count (mcL) Patient First Name Family Name
#  Min.   :4.093          Length:22083       Length:22083
#  1st Qu.:4.763          Class :character   Class :character
#  Median :4.899          Mode  :character   Mode  :character
#  Mean   :4.899
#  3rd Qu.:5.034
#  Max.   :5.610
#
#  Father's name       Mother's age    Father's age   Institute Name
# ...

# %%
 lapply(df,function(x) cbind(summary(x)))
# Out:
# $`Patient Id`
#        [,1]
# Length "22083"
# Class  "character"
# Mode   "character"
#
# $`Patient Age`
#                [,1]
# Min.       0.000000
# 1st Qu.    3.000000
# Median     7.000000
# Mean       6.974148
# 3rd Qu.   11.000000
# Max.      14.000000
# NA's    1427.000000
#
# $`Genes in mother's side`
#        [,1]
# Length "22083"
# Class  "character"
# Mode   "character"
#
# $`Inherited from father`
#        [,1]
# Length "22083"
# Class  "character"
# Mode   "character"
#
# $`Maternal gene`
#        [,1]
# Length "22083"
# Class  "character"
# Mode   "character"
#
# $`Paternal gene`
#        [,1]
# Length "22083"
# Class  "character"
# Mode   "character"
#
# $`Blood cell count (mcL)`
#             [,1]
# Min.    4.092727
# 1st Qu. 4.763109
# Median  4.899399
# Mean    4.898871
# 3rd Qu. 5.033830
# Max.    5.609829
#
# $`Patient First Name`
#        [,1]
# Length "22083"
# Class  "character"
# Mode   "character"
#
# $`Family Name`
#        [,1]
# Length "22083"
# ...

# %%
str(df)
# Out:
# tibble [22,083 x 45] (S3: tbl_df/tbl/data.frame)
#  $ Patient Id                                      : chr [1:22083] "PID0x6418" "PID0x25d5" "PID0x4a82" "PID0x4ac8" ...
#  $ Patient Age                                     : num [1:22083] 2 4 6 12 11 14 3 3 11 4 ...
#  $ Genes in mother's side                          : chr [1:22083] "Yes" "Yes" "Yes" "Yes" ...
#  $ Inherited from father                           : chr [1:22083] "No" "Yes" "No" "No" ...
#  $ Maternal gene                                   : chr [1:22083] "Yes" "No" "No" "Yes" ...
#  $ Paternal gene                                   : chr [1:22083] "No" "No" "No" "No" ...
#  $ Blood cell count (mcL)                          : num [1:22083] 4.76 4.91 4.89 4.71 4.72 ...
#  $ Patient First Name                              : chr [1:22083] "Richard" "Mike" "Kimberly" "Jeffery" ...
#  $ Family Name                                     : chr [1:22083] NA NA NA "Hoelscher" ...
# ...

# %%
drop <- c("Patient Id","Patient First Name","Family Name","Father's name","Institute Name","Location of Institute")
df = df[,!(names(df) %in% drop)]

# %%
drop <- c("Test 1","Test 2","Test 3","Test 4","Test 5","Parental consent","Place of birth")
df = df[,!(names(df) %in% drop)]

# %%
str(df)
# Out:
# tibble [22,083 x 32] (S3: tbl_df/tbl/data.frame)
#  $ Patient Age                                     : num [1:22083] 2 4 6 12 11 14 3 3 11 4 ...
#  $ Genes in mother's side                          : chr [1:22083] "Yes" "Yes" "Yes" "Yes" ...
#  $ Inherited from father                           : chr [1:22083] "No" "Yes" "No" "No" ...
#  $ Maternal gene                                   : chr [1:22083] "Yes" "No" "No" "Yes" ...
#  $ Paternal gene                                   : chr [1:22083] "No" "No" "No" "No" ...
#  $ Blood cell count (mcL)                          : num [1:22083] 4.76 4.91 4.89 4.71 4.72 ...
#  $ Mother's age                                    : num [1:22083] NA NA 41 21 32 NA NA 40 45 44 ...
#  $ Father's age                                    : num [1:22083] NA 23 22 NA NA NA 63 NA 44 42 ...
#  $ Status                                          : chr [1:22083] "Alive" "Deceased" "Alive" "Deceased" ...
# ...

# %%
head(df)
tail(df)
# Out:
#   Patient Age Genes in mother's side Inherited from father Maternal gene
# 1  2          Yes                    No                    Yes
# 2  4          Yes                    Yes                   No
# 3  6          Yes                    No                    No
# 4 12          Yes                    No                    Yes
# 5 11          Yes                    No                    NA
# 6 14          Yes                    No                    Yes
#   Paternal gene Blood cell count (mcL) Mother's age Father's age Status
# 1 No            4.760603               NA           NA           Alive
# 2 No            4.910669               NA           23           Deceased
# 3 No            4.893297               41           22           Alive
# 4 No            4.705280               21           NA           Deceased
# 5 Yes           4.720703               32           NA           Alive
# 6 No            5.103188               NA           NA           Deceased
# ...

# %%
dim(df)
# Out:
# [1] 22083    32

# %%
df <-df %>% drop_na()
head(df)
# Out:
#   Patient Age Genes in mother's side Inherited from father Maternal gene
# 1 11          No                     No                    Yes
# 2  4          No                     Yes                   Yes
# 3  1          Yes                    Yes                   No
# 4  6          Yes                    No                    Yes
# 5 10          Yes                    Yes                   Yes
# 6  6          No                     Yes                   Yes
#   Paternal gene Blood cell count (mcL) Mother's age Father's age Status
# 1 No            5.209058               45           44           Alive
# 2 Yes           4.752272               44           42           Alive
# 3 No            4.612265               50           56           Deceased
# 4 No            4.620420               41           20           Alive
# 5 No            4.751452               40           57           Deceased
# 6 Yes           4.876896               36           48           Deceased
# ...

# %%
 lapply(df,function(x) cbind(summary(x)))
# Out:
# $`Patient Age`
#              [,1]
# Min.     0.000000
# 1st Qu.  3.000000
# Median   7.000000
# Mean     6.922112
# 3rd Qu. 11.000000
# Max.    14.000000
#
# $`Genes in mother's side`
#        [,1]
# Length "6856"
# Class  "character"
# Mode   "character"
#
# $`Inherited from father`
#        [,1]
# Length "6856"
# Class  "character"
# Mode   "character"
#
# $`Maternal gene`
#        [,1]
# Length "6856"
# Class  "character"
# Mode   "character"
#
# $`Paternal gene`
#        [,1]
# Length "6856"
# Class  "character"
# Mode   "character"
#
# $`Blood cell count (mcL)`
#             [,1]
# Min.    4.146230
# 1st Qu. 4.766416
# Median  4.900262
# Mean    4.900848
# 3rd Qu. 5.036382
# Max.    5.609829
#
# $`Mother's age`
#             [,1]
# Min.    18.00000
# 1st Qu. 26.00000
# Median  35.00000
# Mean    34.64863
# 3rd Qu. 43.00000
# Max.    51.00000
#
# $`Father's age`
#             [,1]
# Min.    20.00000
# 1st Qu. 31.00000
# Median  42.00000
# Mean    41.96076
# 3rd Qu. 53.00000
# ...

# %%
names(df) <- gsub(" ", "_", names(df))
names(df) <- gsub("\\(", "_", names(df))
names(df) <- gsub("\\)", "_", names(df))
names(df) <- gsub("\\/", "_", names(df))
names(df) <- gsub("'", "_", names(df))

# %%
ggplot(data = df, aes(Disorder_Subclass,fill = Gender)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
head(df[, c(11:23), drop=FALSE])
# Out:
#   Heart_Rate__rates_min Follow-up Gender    Birth_asphyxia
# 1 Tachycardia           Low       Male      Yes
# 2 Tachycardia           Low       Male      No
# 3 Tachycardia           High      Male      Not available
# 4 Tachycardia           High      Male      No
# 5 Tachycardia           Low       Ambiguous No
# 6 Normal                Low       Ambiguous No
#   Autopsy_shows_birth_defect__if_applicable_
# 1 Not applicable
# 2 Not applicable
# 3 None
# 4 Not applicable
# 5 Yes
# 6 Yes
#   Folic_acid_details__peri-conceptional_ H_O_serious_maternal_illness
# 1 Yes                                    Yes
# 2 Yes                                    No
# 3 Yes                                    No
# 4 Yes                                    Yes
# 5 No                                     No
# 6 Yes                                    Yes
#   H_O_radiation_exposure__x-ray_ H_O_substance_abuse
# 1 No                             No
# 2 No                             No
# ...

# %%
ggplot(data = df, aes(Status,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Birth_defects,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes( Blood_test_result ,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes( History_of_anomalies_in_previous_pregnancies ,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
 
ggplot(data = df, aes(Assisted_conception_IVF_ART ,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(H_O_substance_abuse ,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(H_O_serious_maternal_illness ,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
pairs(df[,!sapply(df,is.character)])
# Out:
# plot without title

# %%
ggplot(data=df, aes(x=Mother_s_age, y=Father_s_age, color=Disorder_Subclass)) + 
  geom_point()
# Out:
# plot without title

# %%
ggplot(data = df, aes(Symptom_1,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Symptom_2,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Symptom_3,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Symptom_4,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Symptom_5,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Symptom_1+Symptom_2,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Disorder_Subclass,fill = factor(Symptom_1))) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Disorder_Subclass,fill = factor(Symptom_5))) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Disorder_Subclass,fill = factor(Symptom_4))) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Disorder_Subclass,fill = factor(Symptom_3))) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Disorder_Subclass,fill = factor(Symptom_2))) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Symptom_5,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Symptom_4,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Symptom_3,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Symptom_2,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
str(df)
# Out:
# tibble [6,856 x 32] (S3: tbl_df/tbl/data.frame)
#  $ Patient_Age                                     : num [1:6856] 11 4 1 6 10 6 10 4 8 1 ...
#  $ Genes_in_mother_s_side                          : chr [1:6856] "No" "No" "Yes" "Yes" ...
#  $ Inherited_from_father                           : chr [1:6856] "No" "Yes" "Yes" "No" ...
#  $ Maternal_gene                                   : chr [1:6856] "Yes" "Yes" "No" "Yes" ...
#  $ Paternal_gene                                   : chr [1:6856] "No" "Yes" "No" "No" ...
#  $ Blood_cell_count__mcL_                          : num [1:6856] 5.21 4.75 4.61 4.62 4.75 ...
#  $ Mother_s_age                                    : num [1:6856] 45 44 50 41 40 36 30 49 18 38 ...
#  $ Father_s_age                                    : num [1:6856] 44 42 56 20 57 48 42 28 31 61 ...
#  $ Status                                          : chr [1:6856] "Alive" "Alive" "Deceased" "Alive" ...
# ...

# %%
ggplot(data = df, aes(Genetic_Disorder,fill = Maternal_gene)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Disorder_Subclass,fill = Maternal_gene)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Genetic_Disorder,fill = Paternal_gene)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Disorder_Subclass,fill = Paternal_gene)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Genetic_Disorder,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
par(mfrow=c(4,1))
p1 <- ggplot(data = df, aes(Symptom_1,fill = Disorder_Subclass)) +
    geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
p2 <- ggplot(data = df, aes(Symptom_2,fill = Disorder_Subclass)) +
    geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
p3 <- ggplot(data = df, aes(Symptom_3,fill = Disorder_Subclass)) +
    geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
p4 <- ggplot(data = df, aes(Symptom_4,fill = Disorder_Subclass)) +
    geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
p5 <- ggplot(data = df, aes(Symptom_5,fill = Disorder_Subclass)) +
    geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
plot(p1)
plot(p2)
plot(p3)
plot(p4)
plot(p5)
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %%
ggplot(df, aes(x=Mother_s_age)) + 
 geom_density(alpha=.2, fill="#FF6666")
# Out:
# plot without title

# %%
ggplot(data = df, aes(Disorder_Subclass,fill = factor(Symptom_1))) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Disorder_Subclass,fill = factor(Symptom_2))) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
# Reshape data from wide to long format
df_long <- df %>%
  pivot_longer(cols = starts_with("Symptom"), names_to = "Symptom", values_to = "Value")

df_filtered <- df_long %>%
  filter(Value == 1)

ggplot(data = df_long, aes(Disorder_Subclass, fill = factor(Symptom), group = Symptom)) +
  geom_bar(data = df_filtered, position = "dodge", width = 0.6, stat = "count") +
  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title

# %%
# Reshape data from wide to long format
df_long <- df %>%
  pivot_longer(cols = starts_with("Symptom"), names_to = "Symptom", values_to = "Value")

# Filter the data to include only rows where Symptom equals 1
df_filtered <- df_long %>%
  filter(Value == 0)

ggplot(data = df_long, aes(Disorder_Subclass, fill = factor(Symptom), group = Symptom)) +
  geom_bar(data = df_filtered, position = "dodge", width = 0.6, stat = "count") +
  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title

# %%
str(df)
# Out:
# tibble [6,856 x 32] (S3: tbl_df/tbl/data.frame)
#  $ Patient_Age                                     : num [1:6856] 11 4 1 6 10 6 10 4 8 1 ...
#  $ Genes_in_mother_s_side                          : chr [1:6856] "No" "No" "Yes" "Yes" ...
#  $ Inherited_from_father                           : chr [1:6856] "No" "Yes" "Yes" "No" ...
#  $ Maternal_gene                                   : chr [1:6856] "Yes" "Yes" "No" "Yes" ...
#  $ Paternal_gene                                   : chr [1:6856] "No" "Yes" "No" "No" ...
#  $ Blood_cell_count__mcL_                          : num [1:6856] 5.21 4.75 4.61 4.62 4.75 ...
#  $ Mother_s_age                                    : num [1:6856] 45 44 50 41 40 36 30 49 18 38 ...
#  $ Father_s_age                                    : num [1:6856] 44 42 56 20 57 48 42 28 31 61 ...
#  $ Status                                          : chr [1:6856] "Alive" "Alive" "Deceased" "Alive" ...
# ...

# %%
df_long <- df %>%
  pivot_longer(cols = c(Genes_in_mother_s_side, Inherited_from_father, Maternal_gene, Paternal_gene),
               names_to = "Gene_type", values_to = "Value")

df_long <- df_long %>% drop_na()
# Convert Value column to factor with levels "yes" and "no"
df_long$Value <- factor(df_long$Value, levels = c("Yes", "No"))

df_filtered <- df_long %>%
  filter(Value == 'Yes')

ggplot(data = df_long, aes(Disorder_Subclass, fill = factor(Gene_type), group = Gene_type)) +
  geom_bar(data = df_filtered, position = "dodge", width = 0.6, stat = "count") +
  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title

# %%
df_long <- df %>%
  pivot_longer(cols = c(Genes_in_mother_s_side, Inherited_from_father, Maternal_gene, Paternal_gene),
               names_to = "Gene_type", values_to = "Value")

df_long <- df_long %>% drop_na()
# Convert Value column to factor with levels "yes" and "no"
df_long$Value <- factor(df_long$Value, levels = c("Yes", "No"))

df_filtered <- df_long %>%
  filter(Value == 'No')

ggplot(data = df_long, aes(Disorder_Subclass, fill = factor(Gene_type), group = Gene_type)) +
  geom_bar(data = df_filtered, position = "dodge", width = 0.6, stat = "count") +
  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title

# %%
ggplot(data = df, aes(Genetic_Disorder,fill = Disorder_Subclass)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 3))
# Out:
# plot without title
