# %%
library(readxl)
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.0     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.1     ✔ tibble    3.1.8
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
df <- read_excel("train.xlsx")

# %%
head(df)
# Out:
#   Patient Id Patient Age Genes in mother's side Inherited from father
# 1 PID0x6418   2          Yes                    No
# 2 PID0x25d5   4          Yes                    Yes
# 3 PID0x4a82   6          Yes                    No
# 4 PID0x4ac8  12          Yes                    No
# 5 PID0x1bf7  11          Yes                    No
# 6 PID0x44fe  14          Yes                    No
#   Maternal gene Paternal gene Blood cell count (mcL) Patient First Name
# 1 Yes           No            4.760603               Richard
# 2 No            No            4.910669               Mike
# 3 No            No            4.893297               Kimberly
# 4 Yes           No            4.705280               Jeffery
# 5 NA            Yes           4.720703               Johanna
# 6 Yes           No            5.103188               Richard
#   Family Name Father's name ⋯ Birth defects
# 1 NA          Larre         ⋯ NA
# 2 NA          Brycen        ⋯ Multiple
# 3 NA          Nashon        ⋯ Singular
# 4 Hoelscher   Aayaan        ⋯ Singular
# 5 Stutzman    Suave         ⋯ Multiple
# 6 NA          Coleston      ⋯ Multiple
#   White Blood cell count (thousand per microliter) Blood test result Symptom 1
# 1  9.857562                                        NA                1
# 2  5.522560                                        normal            1
# 3        NA                                        normal            0
# 4  7.919321                                        inconclusive      0
# 5  4.098210                                        NA                0
# 6 10.272230                                        normal            1
#   Symptom 2 Symptom 3 Symptom 4 Symptom 5
# 1  1        1         1          1
# 2 NA        1         1          0
# 3  1        1         1          1
# 4  0        1         0          0
# 5  0        0         0         NA
# 6  0        0         1          0
#   Genetic Disorder
# 1 Mitochondrial genetic inheritance disorders
# 2 NA
# 3 Multifactorial genetic inheritance disorders
# 4 Mitochondrial genetic inheritance disorders
# 5 Multifactorial genetic inheritance disorders
# 6 Single-gene inheritance diseases
#   Disorder Subclass
# 1 Leber's hereditary optic neuropathy
# 2 Cystic fibrosis
# 3 Diabetes
# 4 Leigh syndrome
# 5 Cancer
# 6 Cystic fibrosis

# %%
df$"Genes in mother's side"<-ifelse(df$"Genes in mother's side"=="Yes",1,0)
df$"Inherited from father"<-ifelse(df$"Inherited from father"=="Yes",1,0)
df$"Maternal gene"<-ifelse(df$"Maternal gene"=="Yes",1,0)
df$"Paternal gene"<-ifelse(df$"Paternal gene"=="Yes",1,0)
head(df)
# Out:
#   Patient Id Patient Age Genes in mother's side Inherited from father
# 1 PID0x6418   2          1                      0
# 2 PID0x25d5   4          1                      1
# 3 PID0x4a82   6          1                      0
# 4 PID0x4ac8  12          1                      0
# 5 PID0x1bf7  11          1                      0
# 6 PID0x44fe  14          1                      0
#   Maternal gene Paternal gene Blood cell count (mcL) Patient First Name
# 1  1            0             4.760603               Richard
# 2  0            0             4.910669               Mike
# 3  0            0             4.893297               Kimberly
# 4  1            0             4.705280               Jeffery
# 5 NA            1             4.720703               Johanna
# 6  1            0             5.103188               Richard
#   Family Name Father's name ⋯ Birth defects
# 1 NA          Larre         ⋯ NA
# 2 NA          Brycen        ⋯ Multiple
# 3 NA          Nashon        ⋯ Singular
# 4 Hoelscher   Aayaan        ⋯ Singular
# 5 Stutzman    Suave         ⋯ Multiple
# 6 NA          Coleston      ⋯ Multiple
#   White Blood cell count (thousand per microliter) Blood test result Symptom 1
# 1  9.857562                                        NA                1
# 2  5.522560                                        normal            1
# 3        NA                                        normal            0
# 4  7.919321                                        inconclusive      0
# 5  4.098210                                        NA                0
# 6 10.272230                                        normal            1
#   Symptom 2 Symptom 3 Symptom 4 Symptom 5
# 1  1        1         1          1
# 2 NA        1         1          0
# 3  1        1         1          1
# 4  0        1         0          0
# 5  0        0         0         NA
# 6  0        0         1          0
#   Genetic Disorder
# 1 Mitochondrial genetic inheritance disorders
# 2 NA
# 3 Multifactorial genetic inheritance disorders
# 4 Mitochondrial genetic inheritance disorders
# 5 Multifactorial genetic inheritance disorders
# 6 Single-gene inheritance diseases
#   Disorder Subclass
# 1 Leber's hereditary optic neuropathy
# 2 Cystic fibrosis
# 3 Diabetes
# 4 Leigh syndrome
# 5 Cancer
# 6 Cystic fibrosis

# %%
summary(df)
# Out:
#   Patient Id         Patient Age     Genes in mother's side
#  Length:22083       Min.   : 0.000   Min.   :0.0000
#  Class :character   1st Qu.: 3.000   1st Qu.:0.0000
#  Mode  :character   Median : 7.000   Median :1.0000
#                     Mean   : 6.974   Mean   :0.5952
#                     3rd Qu.:11.000   3rd Qu.:1.0000
#                     Max.   :14.000   Max.   :1.0000
#                     NA's   :1427
#  Inherited from father Maternal gene    Paternal gene    Blood cell count (mcL)
#  Min.   :0.0000        Min.   :0.0000   Min.   :0.0000   Min.   :4.093
#  1st Qu.:0.0000        1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:4.763
#  Median :0.0000        Median :1.0000   Median :0.0000   Median :4.899
#  Mean   :0.3969        Mean   :0.5524   Mean   :0.4336   Mean   :4.899
#  3rd Qu.:1.0000        3rd Qu.:1.0000   3rd Qu.:1.0000   3rd Qu.:5.034
#  Max.   :1.0000        Max.   :1.0000   Max.   :1.0000   Max.   :5.610
#  NA's   :306           NA's   :2810
#  Patient First Name Family Name        Father's name       Mother's age
#  Length:22083       Length:22083       Length:22083       Min.   :18.00
#  Class :character   Class :character   Class :character   1st Qu.:26.00
#  Mode  :character   Mode  :character   Mode  :character   Median :35.00
#                                                           Mean   :34.53
#                                                           3rd Qu.:43.00
#                                                           Max.   :51.00
#                                                           NA's   :6036
#   Father's age   Institute Name     Location of Institute    Status
#  Min.   :20.00   Length:22083       Length:22083          Length:22083
#  1st Qu.:31.00   Class :character   Class :character      Class :character
#  Median :42.00   Mode  :character   Mode  :character      Mode  :character
#  Mean   :41.97
#  3rd Qu.:53.00
#  Max.   :64.00
#  NA's   :5986
#  Respiratory Rate (breaths/min) Heart Rate (rates/min     Test 1
#  Length:22083                   Length:22083          Min.   :0
#  Class :character               Class :character      1st Qu.:0
#  Mode  :character               Mode  :character      Median :0
#                                                       Mean   :0
#                                                       3rd Qu.:0
#                                                       Max.   :0
#                                                       NA's   :2127
#      Test 2         Test 3         Test 4         Test 5     Parental consent
#  Min.   :0      Min.   :0      Min.   :1      Min.   :0      Length:22083
#  1st Qu.:0      1st Qu.:0      1st Qu.:1      1st Qu.:0      Class :character
#  Median :0      Median :0      Median :1      Median :0      Mode  :character
#  Mean   :0      Mean   :0      Mean   :1      Mean   :0
#  3rd Qu.:0      3rd Qu.:0      3rd Qu.:1      3rd Qu.:0
#  Max.   :0      Max.   :0      Max.   :1      Max.   :0
#  NA's   :2152   NA's   :2147   NA's   :2140   NA's   :2170
#   Follow-up            Gender          Birth asphyxia
#  Length:22083       Length:22083       Length:22083
#  Class :character   Class :character   Class :character
#  Mode  :character   Mode  :character   Mode  :character
#
#
#
#
#  Autopsy shows birth defect (if applicable) Place of birth
#  Length:22083                               Length:22083
#  Class :character                           Class :character
#  Mode  :character                           Mode  :character
#
#
#
#
#  Folic acid details (peri-conceptional) H/O serious maternal illness
#  Length:22083                           Length:22083
#  Class :character                       Class :character
#  Mode  :character                       Mode  :character
#
#
#
#
#  H/O radiation exposure (x-ray) H/O substance abuse Assisted conception IVF/ART
#  Length:22083                   Length:22083        Length:22083
#  Class :character               Class :character    Class :character
#  Mode  :character               Mode  :character    Mode  :character
#
#
#
#
#  History of anomalies in previous pregnancies No. of previous abortion
#  Length:22083                                 Min.   :0.000
#  Class :character                             1st Qu.:1.000
#  Mode  :character                             Median :2.000
#                                               Mean   :2.003
#                                               3rd Qu.:3.000
#                                               Max.   :4.000
#                                               NA's   :2162
#  Birth defects      White Blood cell count (thousand per microliter)
#  Length:22083       Min.   : 3.000
#  Class :character   1st Qu.: 5.425
#  Mode  :character   Median : 7.477
#                     Mean   : 7.486
#                     3rd Qu.: 9.526
#                     Max.   :12.000
#                     NA's   :2148
#  Blood test result    Symptom 1        Symptom 2        Symptom 3
#  Length:22083       Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  Class :character   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000
#  Mode  :character   Median :1.0000   Median :1.0000   Median :1.0000
#                     Mean   :0.5925   Mean   :0.5519   Mean   :0.5362
#                     3rd Qu.:1.0000   3rd Qu.:1.0000   3rd Qu.:1.0000
#                     Max.   :1.0000   Max.   :1.0000   Max.   :1.0000
#                     NA's   :2155     NA's   :2222     NA's   :2101
#    Symptom 4        Symptom 5      Genetic Disorder   Disorder Subclass
#  Min.   :0.0000   Min.   :0.0000   Length:22083       Length:22083
#  1st Qu.:0.0000   1st Qu.:0.0000   Class :character   Class :character
#  Median :0.0000   Median :0.0000   Mode  :character   Mode  :character
#  Mean   :0.4977   Mean   :0.4619
#  3rd Qu.:1.0000   3rd Qu.:1.0000
#  Max.   :1.0000   Max.   :1.0000
#  NA's   :2113     NA's   :2153

# %%
drop <- c("Patient Id","Genes in mother's side","Patient First Name","Family Name","Father's name","Institute Name","Location of Institute")
df = df[,!(names(df) %in% drop)]

# %%
head(df)
# Out:
#   Patient Age Inherited from father Maternal gene Paternal gene
# 1  2          0                      1            0
# 2  4          1                      0            0
# 3  6          0                      0            0
# 4 12          0                      1            0
# 5 11          0                     NA            1
# 6 14          0                      1            0
#   Blood cell count (mcL) Mother's age Father's age Status
# 1 4.760603               NA           NA           Alive
# 2 4.910669               NA           23           Deceased
# 3 4.893297               41           22           Alive
# 4 4.705280               21           NA           Deceased
# 5 4.720703               32           NA           Alive
# 6 5.103188               NA           NA           Deceased
#   Respiratory Rate (breaths/min) Heart Rate (rates/min ⋯ Birth defects
# 1 Normal (30-60)                 Normal                ⋯ NA
# 2 Tachypnea                      Normal                ⋯ Multiple
# 3 Normal (30-60)                 Tachycardia           ⋯ Singular
# 4 Tachypnea                      Normal                ⋯ Singular
# 5 Tachypnea                      Tachycardia           ⋯ Multiple
# 6 NA                             Normal                ⋯ Multiple
#   White Blood cell count (thousand per microliter) Blood test result Symptom 1
# 1  9.857562                                        NA                1
# 2  5.522560                                        normal            1
# 3        NA                                        normal            0
# 4  7.919321                                        inconclusive      0
# 5  4.098210                                        NA                0
# 6 10.272230                                        normal            1
#   Symptom 2 Symptom 3 Symptom 4 Symptom 5
# 1  1        1         1          1
# 2 NA        1         1          0
# 3  1        1         1          1
# 4  0        1         0          0
# 5  0        0         0         NA
# 6  0        0         1          0
#   Genetic Disorder
# 1 Mitochondrial genetic inheritance disorders
# 2 NA
# 3 Multifactorial genetic inheritance disorders
# 4 Mitochondrial genetic inheritance disorders
# 5 Multifactorial genetic inheritance disorders
# 6 Single-gene inheritance diseases
#   Disorder Subclass
# 1 Leber's hereditary optic neuropathy
# 2 Cystic fibrosis
# 3 Diabetes
# 4 Leigh syndrome
# 5 Cancer
# 6 Cystic fibrosis

# %%
drop <- c("Test 1","Test 2","Test 3","Test 4","Test 5","Parental consent","Place of birth")
df = df[,!(names(df) %in% drop)]

# %%
head(df)
tail(df)
# Out:
#   Patient Age Inherited from father Maternal gene Paternal gene
# 1  2          0                      1            0
# 2  4          1                      0            0
# 3  6          0                      0            0
# 4 12          0                      1            0
# 5 11          0                     NA            1
# 6 14          0                      1            0
#   Blood cell count (mcL) Mother's age Father's age Status
# 1 4.760603               NA           NA           Alive
# 2 4.910669               NA           23           Deceased
# 3 4.893297               41           22           Alive
# 4 4.705280               21           NA           Deceased
# 5 4.720703               32           NA           Alive
# 6 5.103188               NA           NA           Deceased
#   Respiratory Rate (breaths/min) Heart Rate (rates/min ⋯ Birth defects
# 1 Normal (30-60)                 Normal                ⋯ NA
# 2 Tachypnea                      Normal                ⋯ Multiple
# 3 Normal (30-60)                 Tachycardia           ⋯ Singular
# 4 Tachypnea                      Normal                ⋯ Singular
# 5 Tachypnea                      Tachycardia           ⋯ Multiple
# 6 NA                             Normal                ⋯ Multiple
#   White Blood cell count (thousand per microliter) Blood test result Symptom 1
# 1  9.857562                                        NA                1
# 2  5.522560                                        normal            1
# 3        NA                                        normal            0
# 4  7.919321                                        inconclusive      0
# 5  4.098210                                        NA                0
# 6 10.272230                                        normal            1
#   Symptom 2 Symptom 3 Symptom 4 Symptom 5
# 1  1        1         1          1
# 2 NA        1         1          0
# 3  1        1         1          1
# 4  0        1         0          0
# 5  0        0         0         NA
# 6  0        0         1          0
#   Genetic Disorder
# 1 Mitochondrial genetic inheritance disorders
# 2 NA
# 3 Multifactorial genetic inheritance disorders
# 4 Mitochondrial genetic inheritance disorders
# 5 Multifactorial genetic inheritance disorders
# 6 Single-gene inheritance diseases
#   Disorder Subclass
# 1 Leber's hereditary optic neuropathy
# 2 Cystic fibrosis
# 3 Diabetes
# 4 Leigh syndrome
# 5 Cancer
# 6 Cystic fibrosis
#   Patient Age Inherited from father Maternal gene Paternal gene
# 1  9          1                     1             1
# 2  4          1                     1             0
# 3  8          1                     0             1
# 4  8          0                     1             0
# 5  7          0                     1             1
# 6 11          0                     0             0
#   Blood cell count (mcL) Mother's age Father's age Status
# 1 5.012599               47           NA           Deceased
# 2 5.258298               35           64           Deceased
# 3 4.974220               NA           56           Alive
# 4 5.186470               35           51           Deceased
# 5 4.858543               19           NA           Alive
# 6 4.738067               32           62           Deceased
#   Respiratory Rate (breaths/min) Heart Rate (rates/min ⋯ Birth defects
# 1 NA                             Normal                ⋯ NA
# 2 Normal (30-60)                 Tachycardia           ⋯ Multiple
# 3 Normal (30-60)                 Normal                ⋯ Multiple
# 4 Tachypnea                      Normal                ⋯ Singular
# 5 Tachypnea                      Tachycardia           ⋯ Multiple
# 6 Normal (30-60)                 Normal                ⋯ Singular
#   White Blood cell count (thousand per microliter) Blood test result Symptom 1
# 1 12.000000                                        slightly abnormal NA
# 2  6.584811                                        inconclusive       0
# 3  7.041556                                        inconclusive       1
# 4  7.715464                                        normal             0
# 5  8.437670                                        abnormal           1
# 6 11.188371                                        normal             1
#   Symptom 2 Symptom 3 Symptom 4 Symptom 5
# 1 1         0         0          0
# 2 0         1         0          0
# 3 1         1         1          0
# 4 0         0         1         NA
# 5 1         1         0          0
# 6 0         1         1          1
#   Genetic Disorder                             Disorder Subclass
# 1 Mitochondrial genetic inheritance disorders  Leigh syndrome
# 2 Mitochondrial genetic inheritance disorders  Leigh syndrome
# 3 Multifactorial genetic inheritance disorders Diabetes
# 4 Mitochondrial genetic inheritance disorders  Mitochondrial myopathy
# 5 NA                                           Leigh syndrome
# 6 Multifactorial genetic inheritance disorders Diabetes

# %%
dim(df)
# Out:
# [1] 22083    31

# %%
summary(df)
# Out:
#   Patient Age     Inherited from father Maternal gene    Paternal gene
#  Min.   : 0.000   Min.   :0.0000        Min.   :0.0000   Min.   :0.0000
#  1st Qu.: 3.000   1st Qu.:0.0000        1st Qu.:0.0000   1st Qu.:0.0000
#  Median : 7.000   Median :0.0000        Median :1.0000   Median :0.0000
#  Mean   : 6.974   Mean   :0.3969        Mean   :0.5524   Mean   :0.4336
#  3rd Qu.:11.000   3rd Qu.:1.0000        3rd Qu.:1.0000   3rd Qu.:1.0000
#  Max.   :14.000   Max.   :1.0000        Max.   :1.0000   Max.   :1.0000
#  NA's   :1427     NA's   :306           NA's   :2810
#  Blood cell count (mcL)  Mother's age    Father's age      Status
#  Min.   :4.093          Min.   :18.00   Min.   :20.00   Length:22083
#  1st Qu.:4.763          1st Qu.:26.00   1st Qu.:31.00   Class :character
#  Median :4.899          Median :35.00   Median :42.00   Mode  :character
#  Mean   :4.899          Mean   :34.53   Mean   :41.97
#  3rd Qu.:5.034          3rd Qu.:43.00   3rd Qu.:53.00
#  Max.   :5.610          Max.   :51.00   Max.   :64.00
#                         NA's   :6036    NA's   :5986
#  Respiratory Rate (breaths/min) Heart Rate (rates/min  Follow-up
#  Length:22083                   Length:22083          Length:22083
#  Class :character               Class :character      Class :character
#  Mode  :character               Mode  :character      Mode  :character
#
#
#
#
#     Gender          Birth asphyxia
#  Length:22083       Length:22083
#  Class :character   Class :character
#  Mode  :character   Mode  :character
#
#
#
#
#  Autopsy shows birth defect (if applicable)
#  Length:22083
#  Class :character
#  Mode  :character
#
#
#
#
#  Folic acid details (peri-conceptional) H/O serious maternal illness
#  Length:22083                           Length:22083
#  Class :character                       Class :character
#  Mode  :character                       Mode  :character
#
#
#
#
#  H/O radiation exposure (x-ray) H/O substance abuse Assisted conception IVF/ART
#  Length:22083                   Length:22083        Length:22083
#  Class :character               Class :character    Class :character
#  Mode  :character               Mode  :character    Mode  :character
#
#
#
#
#  History of anomalies in previous pregnancies No. of previous abortion
#  Length:22083                                 Min.   :0.000
#  Class :character                             1st Qu.:1.000
#  Mode  :character                             Median :2.000
#                                               Mean   :2.003
#                                               3rd Qu.:3.000
#                                               Max.   :4.000
#                                               NA's   :2162
#  Birth defects      White Blood cell count (thousand per microliter)
#  Length:22083       Min.   : 3.000
#  Class :character   1st Qu.: 5.425
#  Mode  :character   Median : 7.477
#                     Mean   : 7.486
#                     3rd Qu.: 9.526
#                     Max.   :12.000
#                     NA's   :2148
#  Blood test result    Symptom 1        Symptom 2        Symptom 3
#  Length:22083       Min.   :0.0000   Min.   :0.0000   Min.   :0.0000
#  Class :character   1st Qu.:0.0000   1st Qu.:0.0000   1st Qu.:0.0000
#  Mode  :character   Median :1.0000   Median :1.0000   Median :1.0000
#                     Mean   :0.5925   Mean   :0.5519   Mean   :0.5362
#                     3rd Qu.:1.0000   3rd Qu.:1.0000   3rd Qu.:1.0000
#                     Max.   :1.0000   Max.   :1.0000   Max.   :1.0000
#                     NA's   :2155     NA's   :2222     NA's   :2101
#    Symptom 4        Symptom 5      Genetic Disorder   Disorder Subclass
#  Min.   :0.0000   Min.   :0.0000   Length:22083       Length:22083
#  1st Qu.:0.0000   1st Qu.:0.0000   Class :character   Class :character
#  Median :0.0000   Median :0.0000   Mode  :character   Mode  :character
#  Mean   :0.4977   Mean   :0.4619
#  3rd Qu.:1.0000   3rd Qu.:1.0000
#  Max.   :1.0000   Max.   :1.0000
#  NA's   :2113     NA's   :2153

# %%
df <- subset(df, !is.na("Genetic Disorder") & !is.na("Disorder Subclass"))
dim(df)
# Out:
# [1] 22083    31

# %%
n_distinct(df$'Genetic Disorder')
df %>% drop_na('Genetic Disorder')
# Out:
# [1] 4
#       Patient Age Inherited from father Maternal gene Paternal gene
# 1      2          0                      1            0
# 2      6          0                      0            0
# 3     12          0                      1            0
# 4     11          0                     NA            1
# 5     14          0                      1            0
# 6      3          0                      1            1
# 7      3          0                      1            1
# 8     11          0                      1            0
# 9      4          1                      1            1
# 10     6          0                     NA            0
# 11     7          0                      0            1
# 12     1          1                      0            0
# 13     6          0                      1            0
# 14     0          0                      0            0
# 15     0          1                      0            0
# 16    NA          0                      0            0
# 17    10          1                      1            0
# 18     6          1                      1            1
# 19     2          0                      1            0
# 20    10          1                      1            0
# 21    NA          0                      0            0
# 22     4          1                      1            0
# 23     5          1                      1            1
# 24    13          0                     NA            0
# 25    NA          0                     NA            1
# 26    11          1                      0            0
# 27    NA          0                      0            0
# 28     4          0                      1            0
# 29    11          1                     NA            1
# 30     8          1                      0            1
# ⋮     ⋮           ⋮                     ⋮             ⋮
# 19908  2          1                      1            1
# 19909 10          1                      0            0
# 19910 14          0                      0            0
# 19911 10          0                      1            0
# 19912 12          0                      1            0
# 19913  7          0                      0            0
# 19914 12          0                      1            0
# 19915  6          1                      0            1
# 19916 11          0                      1            1
# 19917 NA          1                      1            0
# 19918  4          0                      1            1
# 19919 11          0                      1            1
# 19920 NA          1                      0            1
# 19921 13          0                      0            0
# 19922  2          1                     NA            0
# 19923  9          0                      0            1
# 19924 13          1                      0            1
# 19925  0          0                     NA            1
# 19926  4          0                      0            0
# 19927  7          1                      1            0
# 19928  0          0                      1            1
# 19929  6          0                     NA            0
# 19930  4          0                     NA            0
# 19931 10          0                      1            1
# 19932  0          0                      1            0
# 19933  9          1                      1            1
# 19934  4          1                      1            0
# 19935  8          1                      0            1
# 19936  8          0                      1            0
# 19937 11          0                      0            0
#       Blood cell count (mcL) Mother's age Father's age Status
# 1     4.760603               NA           NA           Alive
# 2     4.893297               41           22           Alive
# 3     4.705280               21           NA           Deceased
# 4     4.720703               32           NA           Alive
# 5     5.103188               NA           NA           Deceased
# 6     4.901080               NA           63           Alive
# 7     4.964816               40           NA           Alive
# 8     5.209058               45           44           Alive
# 9     4.752272               44           42           Alive
# 10    4.750824               NA           NA           Deceased
# 11    4.848795               NA           NA           Deceased
# 12    4.612265               50           56           Deceased
# 13    4.620420               41           20           Alive
# 14    4.918570               30           24           Alive
# 15    4.798520               NA           57           Alive
# 16    4.952457               24           24           Deceased
# 17    4.751452               40           57           Deceased
# 18    4.876896               36           48           Deceased
# 19    4.808872               NA           30           Alive
# 20    5.077720               30           42           Deceased
# 21    4.998895               NA           NA           Alive
# 22    4.963480               NA           55           Alive
# 23    4.661035               NA           62           Alive
# 24    4.854488               NA           43           Deceased
# 25    4.710696               NA           32           Alive
# 26    5.117909               51           41           Deceased
# 27    4.991328               23           52           Deceased
# 28    4.658102               49           28           Deceased
# 29    4.839044               46           42           Alive
# 30    4.720877               18           31           Deceased
# ⋮     ⋮                      ⋮            ⋮            ⋮
# 19908 5.085562               26           NA           Deceased
# 19909 4.881958               44           55           Deceased
# 19910 5.056440               35           37           Deceased
# 19911 4.885266               45           39           Alive
# 19912 4.730481               18           26           Deceased
# 19913 4.713334               27           56           Alive
# 19914 4.652915               49           40           Alive
# 19915 5.117296               48           27           Alive
# 19916 4.737274               25           40           Deceased
# 19917 4.813765               38           NA           Deceased
# 19918 5.012408               47           64           Alive
# 19919 4.850192               NA           35           Deceased
# 19920 4.905743               18           NA           Alive
# 19921 4.710362               43           NA           Deceased
# 19922 5.168511               NA           NA           Alive
# 19923 4.876575               NA           NA           Alive
# 19924 4.777036               27           58           Alive
# 19925 4.839422               42           NA           Deceased
# 19926 5.077554               44           34           Deceased
# 19927 4.656876               46           33           Deceased
# 19928 5.084669               NA           NA           Deceased
# 19929 4.828224               34           45           Deceased
# 19930 4.789307               35           51           Alive
# 19931 4.643860               49           NA           Deceased
# 19932 4.931758               NA           50           Alive
# 19933 5.012599               47           NA           Deceased
# 19934 5.258298               35           64           Deceased
# 19935 4.974220               NA           56           Alive
# 19936 5.186470               35           51           Deceased
# 19937 4.738067               32           62           Deceased
#       Respiratory Rate (breaths/min) Heart Rate (rates/min ⋯ Birth defects
# 1     Normal (30-60)                 Normal                ⋯ NA
# 2     Normal (30-60)                 Tachycardia           ⋯ Singular
# 3     Tachypnea                      Normal                ⋯ Singular
# 4     Tachypnea                      Tachycardia           ⋯ Multiple
# 5     NA                             Normal                ⋯ Multiple
# 6     Normal (30-60)                 NA                    ⋯ Multiple
# 7     Tachypnea                      Normal                ⋯ Singular
# 8     Tachypnea                      Tachycardia           ⋯ Multiple
# 9     Tachypnea                      Tachycardia           ⋯ Multiple
# 10    Tachypnea                      NA                    ⋯ Singular
# 11    Normal (30-60)                 Tachycardia           ⋯ Multiple
# 12    Normal (30-60)                 Tachycardia           ⋯ Singular
# 13    Tachypnea                      Tachycardia           ⋯ Multiple
# 14    Normal (30-60)                 Tachycardia           ⋯ Multiple
# 15    Normal (30-60)                 NA                    ⋯ Multiple
# 16    Tachypnea                      Normal                ⋯ NA
# 17    Normal (30-60)                 Tachycardia           ⋯ Singular
# 18    Tachypnea                      Normal                ⋯ Singular
# 19    Tachypnea                      Tachycardia           ⋯ NA
# 20    Tachypnea                      Tachycardia           ⋯ Multiple
# 21    Tachypnea                      Normal                ⋯ Multiple
# 22    Tachypnea                      NA                    ⋯ Multiple
# 23    NA                             Normal                ⋯ Multiple
# 24    Normal (30-60)                 Tachycardia           ⋯ Singular
# 25    Normal (30-60)                 Tachycardia           ⋯ Multiple
# 26    Tachypnea                      Tachycardia           ⋯ NA
# 27    NA                             NA                    ⋯ NA
# 28    Normal (30-60)                 Normal                ⋯ Multiple
# 29    Tachypnea                      Normal                ⋯ Multiple
# 30    Normal (30-60)                 Normal                ⋯ Singular
# ⋮     ⋮                              ⋮                     ⋱ ⋮
# 19908 Normal (30-60)                 Normal                ⋯ Singular
# 19909 Tachypnea                      Tachycardia           ⋯ Multiple
# 19910 Tachypnea                      Tachycardia           ⋯ Singular
# 19911 Tachypnea                      Tachycardia           ⋯ Singular
# 19912 Tachypnea                      Tachycardia           ⋯ Multiple
# 19913 Normal (30-60)                 Tachycardia           ⋯ Singular
# 19914 Normal (30-60)                 Normal                ⋯ Multiple
# 19915 Tachypnea                      Tachycardia           ⋯ Singular
# 19916 Tachypnea                      Normal                ⋯ Singular
# 19917 Normal (30-60)                 NA                    ⋯ Multiple
# 19918 Normal (30-60)                 Normal                ⋯ Singular
# 19919 Tachypnea                      Normal                ⋯ Singular
# 19920 Normal (30-60)                 Tachycardia           ⋯ Multiple
# 19921 NA                             Normal                ⋯ Singular
# 19922 Normal (30-60)                 Tachycardia           ⋯ Multiple
# 19923 Normal (30-60)                 Tachycardia           ⋯ Singular
# 19924 Normal (30-60)                 Normal                ⋯ Singular
# 19925 Tachypnea                      Normal                ⋯ Multiple
# 19926 Normal (30-60)                 Normal                ⋯ Singular
# 19927 Tachypnea                      Normal                ⋯ NA
# 19928 Tachypnea                      Tachycardia           ⋯ Singular
# 19929 Tachypnea                      Normal                ⋯ Singular
# 19930 Tachypnea                      Normal                ⋯ Multiple
# 19931 NA                             Normal                ⋯ Multiple
# 19932 Normal (30-60)                 Tachycardia           ⋯ Singular
# 19933 NA                             Normal                ⋯ NA
# 19934 Normal (30-60)                 Tachycardia           ⋯ Multiple
# 19935 Normal (30-60)                 Normal                ⋯ Multiple
# 19936 Tachypnea                      Normal                ⋯ Singular
# 19937 Normal (30-60)                 Normal                ⋯ Singular
#       White Blood cell count (thousand per microliter) Blood test result
# 1      9.857562                                        NA
# 2            NA                                        normal
# 3      7.919321                                        inconclusive
# 4      4.098210                                        NA
# 5     10.272230                                        normal
# 6      6.825974                                        normal
# 7      9.836352                                        inconclusive
# 8      6.669552                                        slightly abnormal
# 9      6.397702                                        abnormal
# 10     5.957321                                        abnormal
# 11     8.409691                                        slightly abnormal
# 12     7.995115                                        slightly abnormal
# 13     3.000000                                        slightly abnormal
# 14           NA                                        normal
# 15           NA                                        normal
# 16    10.031078                                        inconclusive
# 17     9.382407                                        abnormal
# 18     7.370477                                        normal
# 19     9.566103                                        slightly abnormal
# 20     7.127898                                        slightly abnormal
# 21     8.652478                                        inconclusive
# 22    10.312571                                        abnormal
# 23     8.513922                                        abnormal
# 24           NA                                        slightly abnormal
# 25    11.373537                                        normal
# 26     6.872168                                        normal
# 27     6.066614                                        abnormal
# 28     9.282477                                        slightly abnormal
# 29           NA                                        abnormal
# 30     5.091219                                        slightly abnormal
# ⋮     ⋮                                                ⋮
# 19908 11.374331                                        normal
# 19909  9.094955                                        NA
# 19910  8.992224                                        abnormal
# 19911  8.996376                                        normal
# 19912 11.762756                                        inconclusive
# 19913  9.342662                                        normal
# 19914  8.035952                                        slightly abnormal
# 19915  3.453291                                        slightly abnormal
# 19916  8.131379                                        abnormal
# 19917  7.461779                                        normal
# 19918  9.066313                                        NA
# 19919  5.982253                                        normal
# 19920  9.300294                                        slightly abnormal
# 19921  6.962753                                        slightly abnormal
# 19922  9.826694                                        slightly abnormal
# 19923 10.847926                                        abnormal
# 19924  3.000736                                        normal
# 19925        NA                                        inconclusive
# 19926  9.566549                                        inconclusive
# 19927  3.003857                                        inconclusive
# 19928  9.393462                                        abnormal
# 19929  5.673544                                        abnormal
# 19930        NA                                        normal
# 19931  9.581455                                        abnormal
# 19932 11.649052                                        abnormal
# 19933 12.000000                                        slightly abnormal
# 19934  6.584811                                        inconclusive
# 19935  7.041556                                        inconclusive
# 19936  7.715464                                        normal
# 19937 11.188371                                        normal
#       Symptom 1 Symptom 2 Symptom 3 Symptom 4 Symptom 5
# 1     1          1        1          1         1
# 2     0          1        1          1         1
# 3     0          0        1          0         0
# 4     0          0        0          0        NA
# 5     1          0        0          1         0
# 6     0          0        0          0         0
# 7     0          0        1         NA         0
# 8     1          1        1          0         1
# 9     0          0        1          1         1
# 10    1         NA        0          0        NA
# 11    0          1        1          1         1
# 12    1          1        0          1         0
# 13    1          0        1          0         1
# 14    0         NA        0         NA         1
# 15    1          1        1         NA         1
# 16    1          1        0          1         1
# 17    1          1        0          0         0
# 18    1          0        0          0         0
# 19    1          0        0          1         0
# 20    1          1        1          1         1
# 21    0          1        1         NA         0
# 22    0          1        0          0         1
# 23    1          0        0          0         0
# 24    0          1        0          0         0
# 25    1         NA        0          0         0
# 26    0          1        1          1        NA
# 27    0          0        1          1         1
# 28    1          0        0          1         0
# 29    0         NA        0          0         0
# 30    1          0        1          0         0
# ⋮     ⋮         ⋮         ⋮         ⋮         ⋮
# 19908 NA        NA         1        NA         0
# 19909  0         1         0         1         1
# 19910  1         1         1         0         0
# 19911  0        NA        NA        NA         1
# 19912  0         0         1         0         1
# 19913  1         1         1         0         0
# 19914  0         1         1         1         0
# 19915  0         0         1         1         0
# 19916  0        NA         1         0         0
# 19917  1         1         1         1         1
# 19918  0        NA         1         0         0
# 19919  0         0         1         1         1
# 19920  1         1         0         1         0
# 19921  1        NA         0         1         1
# 19922  1         0         1         0         0
# 19923  1         0         0         1        NA
# 19924  0         0         0         0         1
# 19925  1         0         1         0         0
# 19926  1         1         1         1         1
# 19927  1         0         0         1         0
# 19928  1         1         0        NA         1
# 19929  1         0         0         1         0
# 19930  0         0         1         0         0
# 19931  1         0         0         0        NA
# 19932  1         1         0         1         0
# 19933 NA         1         0         0         0
# 19934  0         0         1         0         0
# 19935  1         1         1         1         0
# 19936  0         0         0         1        NA
# 19937  1         0         1         1         1
#       Genetic Disorder
# 1     Mitochondrial genetic inheritance disorders
# 2     Multifactorial genetic inheritance disorders
# 3     Mitochondrial genetic inheritance disorders
# 4     Multifactorial genetic inheritance disorders
# 5     Single-gene inheritance diseases
# 6     Single-gene inheritance diseases
# 7     Single-gene inheritance diseases
# 8     Mitochondrial genetic inheritance disorders
# 9     Multifactorial genetic inheritance disorders
# 10    Single-gene inheritance diseases
# 11    Single-gene inheritance diseases
# 12    Mitochondrial genetic inheritance disorders
# 13    Mitochondrial genetic inheritance disorders
# 14    Mitochondrial genetic inheritance disorders
# 15    Single-gene inheritance diseases
# 16    Single-gene inheritance diseases
# 17    Mitochondrial genetic inheritance disorders
# 18    Single-gene inheritance diseases
# 19    Single-gene inheritance diseases
# 20    Single-gene inheritance diseases
# 21    Mitochondrial genetic inheritance disorders
# 22    Mitochondrial genetic inheritance disorders
# 23    Mitochondrial genetic inheritance disorders
# 24    Single-gene inheritance diseases
# 25    Single-gene inheritance diseases
# 26    Single-gene inheritance diseases
# 27    Single-gene inheritance diseases
# 28    Mitochondrial genetic inheritance disorders
# 29    Mitochondrial genetic inheritance disorders
# 30    Mitochondrial genetic inheritance disorders
# ⋮     ⋮
# 19908 Single-gene inheritance diseases
# 19909 Single-gene inheritance diseases
# 19910 Single-gene inheritance diseases
# 19911 Mitochondrial genetic inheritance disorders
# 19912 Mitochondrial genetic inheritance disorders
# 19913 Mitochondrial genetic inheritance disorders
# 19914 Mitochondrial genetic inheritance disorders
# 19915 Mitochondrial genetic inheritance disorders
# 19916 Mitochondrial genetic inheritance disorders
# 19917 Mitochondrial genetic inheritance disorders
# 19918 Single-gene inheritance diseases
# 19919 Mitochondrial genetic inheritance disorders
# 19920 Mitochondrial genetic inheritance disorders
# 19921 Mitochondrial genetic inheritance disorders
# 19922 Mitochondrial genetic inheritance disorders
# 19923 Mitochondrial genetic inheritance disorders
# 19924 Mitochondrial genetic inheritance disorders
# 19925 Single-gene inheritance diseases
# 19926 Multifactorial genetic inheritance disorders
# 19927 Mitochondrial genetic inheritance disorders
# 19928 Mitochondrial genetic inheritance disorders
# 19929 Mitochondrial genetic inheritance disorders
# 19930 Single-gene inheritance diseases
# 19931 Mitochondrial genetic inheritance disorders
# 19932 Mitochondrial genetic inheritance disorders
# 19933 Mitochondrial genetic inheritance disorders
# 19934 Mitochondrial genetic inheritance disorders
# 19935 Multifactorial genetic inheritance disorders
# 19936 Mitochondrial genetic inheritance disorders
# 19937 Multifactorial genetic inheritance disorders
#       Disorder Subclass
# 1     Leber's hereditary optic neuropathy
# 2     Diabetes
# 3     Leigh syndrome
# 4     Cancer
# 5     Cystic fibrosis
# 6     Tay-Sachs
# 7     Tay-Sachs
# 8     Leigh syndrome
# 9     Diabetes
# 10    Hemochromatosis
# 11    Cystic fibrosis
# 12    Leigh syndrome
# 13    Leigh syndrome
# 14    Mitochondrial myopathy
# 15    Cystic fibrosis
# 16    Cystic fibrosis
# 17    Mitochondrial myopathy
# 18    Hemochromatosis
# 19    Hemochromatosis
# 20    Cystic fibrosis
# 21    Leigh syndrome
# 22    Mitochondrial myopathy
# 23    Mitochondrial myopathy
# 24    NA
# 25    Tay-Sachs
# 26    Tay-Sachs
# 27    Cystic fibrosis
# 28    Mitochondrial myopathy
# 29    Mitochondrial myopathy
# 30    Mitochondrial myopathy
# ⋮     ⋮
# 19908 Cystic fibrosis
# 19909 NA
# 19910 Tay-Sachs
# 19911 Mitochondrial myopathy
# 19912 Mitochondrial myopathy
# 19913 Leigh syndrome
# 19914 Leigh syndrome
# 19915 Mitochondrial myopathy
# 19916 Leigh syndrome
# 19917 Leber's hereditary optic neuropathy
# 19918 Tay-Sachs
# 19919 Leigh syndrome
# 19920 Mitochondrial myopathy
# 19921 Leigh syndrome
# 19922 Leigh syndrome
# 19923 Mitochondrial myopathy
# 19924 Leigh syndrome
# 19925 Tay-Sachs
# 19926 Diabetes
# 19927 Leigh syndrome
# 19928 Leigh syndrome
# 19929 Mitochondrial myopathy
# 19930 Hemochromatosis
# 19931 Mitochondrial myopathy
# 19932 Leigh syndrome
# 19933 Leigh syndrome
# 19934 Leigh syndrome
# 19935 Diabetes
# 19936 Mitochondrial myopathy
# 19937 Diabetes

# %%
n_distinct(df$'Genetic Disorder')
# Out:
# [1] 4

# %%
class(df$'Genetic Disorder')
# Out:
# [1] "character"

# %%
names(df) <- gsub(" ", "_", names(df))

# %%
library(ggplot2)
library(grid)
ggplot(data = df, aes(Genetic_Disorder,fill = Gender)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 2))
# Out:
# plot without title

# %%
df %>% summarise(across(everything(), ~ sum(is.na(.))))
# Out:
#   Patient_Age Inherited_from_father Maternal_gene Paternal_gene
# 1 1427        306                   2810          0
#   Blood_cell_count_(mcL) Mother's_age Father's_age Status
# 1 0                      6036         5986         0
#   Respiratory_Rate_(breaths/min) Heart_Rate_(rates/min ⋯ Birth_defects
# 1 2149                           2113                  ⋯ 2154
#   White_Blood_cell_count_(thousand_per_microliter) Blood_test_result Symptom_1
# 1 2148                                             2145              2155
#   Symptom_2 Symptom_3 Symptom_4 Symptom_5 Genetic_Disorder Disorder_Subclass
# 1 2222      2101      2113      2153      2146             2168

# %%
sapply(df, function(x) sum(is.na(x)))
# Out:
#                                      Patient_Age
#                                             1427
#                            Inherited_from_father
#                                              306
#                                    Maternal_gene
#                                             2810
#                                    Paternal_gene
#                                                0
#                           Blood_cell_count_(mcL)
#                                                0
#                                     Mother's_age
#                                             6036
#                                     Father's_age
#                                             5986
#                                           Status
#                                                0
#                   Respiratory_Rate_(breaths/min)
#                                             2149
#                            Heart_Rate_(rates/min
#                                             2113
#                                        Follow-up
#                                             2166
#                                           Gender
#                                             2173
#                                   Birth_asphyxia
#                                             2139
#       Autopsy_shows_birth_defect_(if_applicable)
#                                             1026
#           Folic_acid_details_(peri-conceptional)
#                                             2117
#                     H/O_serious_maternal_illness
#                                             2152
#                   H/O_radiation_exposure_(x-ray)
#                                             2153
#                              H/O_substance_abuse
#                                             2195
#                      Assisted_conception_IVF/ART
#                                             2122
#     History_of_anomalies_in_previous_pregnancies
#                                             2172
#                         No._of_previous_abortion
#                                             2162
#                                    Birth_defects
#                                             2154
# White_Blood_cell_count_(thousand_per_microliter)
#                                             2148
#                                Blood_test_result
#                                             2145
#                                        Symptom_1
#                                             2155
#                                        Symptom_2
#                                             2222
#                                        Symptom_3
#                                             2101
#                                        Symptom_4
#                                             2113
#                                        Symptom_5
#                                             2153
#                                 Genetic_Disorder
#                                             2146
#                                Disorder_Subclass
#                                             2168

# %%
head(df[, c(11:23), drop=FALSE])
# Out:
#   Follow-up Gender Birth_asphyxia Autopsy_shows_birth_defect_(if_applicable)
# 1 High      NA     NA             Not applicable
# 2 High      NA     No             None
# 3 Low       NA     No record      Not applicable
# 4 High      Male   Not available  No
# 5 Low       Male   Not available  Not applicable
# 6 Low       Female Not available  None
#   Folic_acid_details_(peri-conceptional) H/O_serious_maternal_illness
# 1 No                                     NA
# 2 Yes                                    Yes
# 3 Yes                                    No
# 4 No                                     Yes
# 5 No                                     Yes
# 6 No                                     No
#   H/O_radiation_exposure_(x-ray) H/O_substance_abuse
# 1 No                             No
# 2 Not applicable                 Not applicable
# 3 Yes                            NA
# 4 -                              Not applicable
# 5 -                              Not applicable
# 6 No                             No
#   Assisted_conception_IVF/ART History_of_anomalies_in_previous_pregnancies
# 1 No                          Yes
# 2 No                          Yes
# 3 Yes                         Yes
# 4 NA                          Yes
# 5 Yes                         No
# 6 NA                          No
#   No._of_previous_abortion Birth_defects
# 1 NA                       NA
# 2 NA                       Multiple
# 3  4                       Singular
# 4  1                       Singular
# 5  4                       Multiple
# 6  0                       Multiple
#   White_Blood_cell_count_(thousand_per_microliter)
# 1  9.857562
# 2  5.522560
# 3        NA
# 4  7.919321
# 5  4.098210
# 6 10.272230

# %%
ggplot(data = df, aes(Disorder_Subclass,fill = Gender)) +
geom_bar(width = 0.6)+  scale_x_discrete(guide = guide_axis(n.dodge = 5))
# Out:
# plot without title

# %%
#load libraries
library(GGally)

#create pairs plot
ggpairs(df[, 25:29])

#. Another one is the polychoric correlation, which calculates the correlation between ordinal categorical variables.
#Ordinal variables are variables whose possible values have a natural order, such as education level or income group. 
#You can use the polycor package in R to compute polychoric correlations. For example, 
#you can use this code to compute the polychoric correlation between two ordinal variables x and y:
#library(polycor)
#polycor(x, y)
# Out:
# Warning message:
# "Removed 2155 rows containing non-finite values (`stat_density()`)."
# Warning message in ggally_statistic(data = data, mapping = mapping, na.rm = na.rm, :
# "Removed 4045 rows containing missing values"
# Warning message in ggally_statistic(data = data, mapping = mapping, na.rm = na.rm, :
# "Removed 3977 rows containing missing values"
# Warning message in ggally_statistic(data = data, mapping = mapping, na.rm = na.rm, :
# "Removed 3991 rows containing missing values"
# Warning message in ggally_statistic(data = data, mapping = mapping, na.rm = na.rm, :
# "Removed 4036 rows containing missing values"
# Warning message:
# "Removed 4045 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 2222 rows containing non-finite values (`stat_density()`)."
# Warning message in ggally_statistic(data = data, mapping = mapping, na.rm = na.rm, :
# "Removed 4028 rows containing missing values"
# Warning message in ggally_statistic(data = data, mapping = mapping, na.rm = na.rm, :
# "Removed 4055 rows containing missing values"
# Warning message in ggally_statistic(data = data, mapping = mapping, na.rm = na.rm, :
# "Removed 4066 rows containing missing values"
# Warning message:
# "Removed 3977 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 4028 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 2101 rows containing non-finite values (`stat_density()`)."
# Warning message in ggally_statistic(data = data, mapping = mapping, na.rm = na.rm, :
# "Removed 3944 rows containing missing values"
# Warning message in ggally_statistic(data = data, mapping = mapping, na.rm = na.rm, :
# "Removed 3982 rows containing missing values"
# Warning message:
# "Removed 3991 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 4055 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 3944 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 2113 rows containing non-finite values (`stat_density()`)."
# Warning message in ggally_statistic(data = data, mapping = mapping, na.rm = na.rm, :
# "Removed 3958 rows containing missing values"
# Warning message:
# "Removed 4036 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 4066 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 3982 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 3958 rows containing missing values (`geom_point()`)."
# Warning message:
# "Removed 2153 rows containing non-finite values (`stat_density()`)."
# plot without title
